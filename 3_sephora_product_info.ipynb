# %%
from bs4 import BeautifulSoup
from random import randint, shuffle
from time import sleep
import re
import pandas as pd
import json
import math
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os
from tqdm import tqdm_notebook as tqdm
import shutil
import numpy as np


pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", -1)
pd.set_option("display.float_format", "{:,.2f}".format)
pd.set_option("display.max_info_rows", 200)

# %%
import sephora_scrape as scrape
# %reload_ext autoreload
# %autoreload 2

# %%
json_folder = "/Users/valmadrid/DataScienceBootcamp/Projects/Gift Recommendation/Gift-Recommendation/json/"
if not os.path.exists(json_folder):
    print("check file path")

# %%
test_json = "P04897543.json"

with open(json_folder+test_json) as json_file:
    data = json.load(json_file)

# %%
k,v= iter(data.keys()), iter(data.values())

while True:
    try:
        display(next(k),next(v))
        print("\n")
    except StopIteration:
            break
# Out:
# 'seoProductName'
# 'pro-filtr-instant-retouch-primer-P04897543'
# 'ancillarySkus'
# [{'biExclusiveLevel': 'none',
#   'brandName': 'FENTY BEAUTY by Rihanna',
#   'image': '/productimages/sku/s2268035-main-Sgrid.jpg',
#   'isAppExclusive': False,
#   'isBiOnly': False,
#   'isFirstAccess': False,
#   'isFree': False,
#   'isLimitedEdition': False,
#   'isLimitedQuantity': False,
#   'isLimitedTimeOffer': False,
#   'isNew': False,
#   'isOnlineOnly': False,
#   'isOnlyFewLeft': False,
#   'isOutOfStock': False,
#   'isSephoraExclusive': True,
#   'listPrice': '$35.00',
#   'maxPurchaseQuantity': 10,
#   'productId': 'P448702',
#   'productName': "Pro Filt'r Hydrating Longwear Foundation",
#   'size': '1.08 oz/ 32 mL',
#   'skuId': '2268035',
#   'skuImages': {'image135': '/productimages/sku/s2268035-main-grid.jpg',
#    'image162': '/productimages/sku/s2268035-162.jpg',
#    'image250': '/productimages/sku/s2268035-main-hero.jpg',
# ...

# %%
downloaded_json = [file for file in os.listdir(json_folder) if file.endswith(".json")]
downloaded_json.sort()
products_detailed_list = []

for filename in tqdm(downloaded_json):
    file_dict = scrape.download_json(filename, json_folder)
    products_detailed_list.append(file_dict)

df_products_detailed = pd.DataFrame(products_detailed_list).sort_values(["brand_id", "id"])
df_products_detailed.to_csv("products_detailed.csv", index=False)

# %%
df_products_detailed
# Out:
#            id  \
# 161   P180726
# 227   P224900
# 276   P237121
# 311   P257520
# 374   P273900
# ...       ...
# 3733  P440068
# 3734  P440069
# 3790  P440652
# 3791  P440653
# 3792  P440657
#
#                                                                           name  \
# 161   Pour Homme II
# 227   Gucci By Gucci Pour Homme
# 276   Flora By Gucci Eau de Toilette
# 311   Flora by Gucci Eau de Parfum
# 374   Guilty
# ...      ...
# 3733  Deep Cleansing Wash
# 3734  Deep Cleansing Face Wash
# 3790  Proactiv Solution 3-Step Acne Treatment System, 90 Day Size
# 3791  Proactiv Solution 3-Step Acne Treatment System, 30 Day Introductory Size
# 3792  ProactivMD 3-Piece Kit, 30 Day Introductory Size
#
#      brand_id brand_name  \
# 161   1063     Gucci
# 227   1063     Gucci
# 276   1063     Gucci
# 311   1063     Gucci
# 374   1063     Gucci
# ...    ...       ...
# 3733  8018     Proactiv
# 3734  8018     Proactiv
# 3790  8018     Proactiv
# 3791  8018     Proactiv
# ...

# %%
df_products_detailed.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6029 entries, 161 to 3792
# Data columns (total 25 columns):
# id                    6029 non-null object
# name                  6029 non-null object
# brand_id              6029 non-null object
# brand_name            6029 non-null object
# short_desc            6029 non-null object
# long_desc             6029 non-null object
# item                  6029 non-null object
# item_name             6029 non-null object
# list_price            6029 non-null float64
# variation             6029 non-null object
# variants              2708 non-null object
# price_low             6029 non-null float64
# price_high            6029 non-null float64
# is_limited_edition    6029 non-null int64
# is_natural_organic    6029 non-null int64
# is_natural_sephora    6029 non-null int64
# rating                5912 non-null float64
# review_count          6029 non-null int64
# user_favorites        6029 non-null int64
# ...
